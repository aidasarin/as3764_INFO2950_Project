# %% [markdown]
# # Phase II of INFO2950 Project
# ### by Aida Sarinzhipova (as3764) and Kyuman Kim (kk946)
#
# **Possible Research Questions**
# 1. Which genre is most influential in affects the other variables (view counts, revenue, rating)
# 2. Which genre got popular overtime?
# 3. How has the popularity of a movie genre affected the rise and fall of other genres?
# 4. How does the genre of a movie influence its success?

# %% [markdown]
# ## Data Cleaning
# In the cells below, we organized data from 'The Movie Database' (TMDB) and 'the Internet Movie Database' (IMDb) retrieved from Kaggle.

# %%
# to load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
# load data
raw_movie_data = pd.read_csv("tmdb_5000_movies.csv")
raw_cast_data = pd.read_csv("tmdb_5000_credits.csv")

# %%
raw_movie_data.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
# restructuring the column order in one dataset and only keeping the columns we need
raw_movie_data = raw_movie_data[['id', 'original_title', 'runtime', 'genres', 'production_companies', 'release_date', 'popularity', 'vote_average', 'vote_count']]

# %%
# changing a column name in the raw cast dataset to have one same column within two datasets for merging
raw_cast_data = raw_cast_data.rename(columns={'movie_id':'id'})

# %%
raw_cast_data.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
#merging the two datasets based on the movie "id"
combined_data = raw_movie_data.merge(raw_cast_data, how = 'outer')
combined_data.head()
# Out:
#        id                            original_title  runtime  \
# 0   19995                                    Avatar    162.0
# 1     285  Pirates of the Caribbean: At World's End    169.0
# 2  206647                                   Spectre    148.0
# 3   49026                     The Dark Knight Rises    165.0
# 4   49529                               John Carter    132.0
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                 production_companies release_date  popularity  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...   2009-12-10  150.437577
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...   2007-05-19  139.082615
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...   2015-10-26  107.376788
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...   2012-07-16  112.312950
# 4        [{"name": "Walt Disney Pictures", "id": 2}]   2012-03-07   43.926995
#
#    vote_average  vote_count                                     title  \
# 0           7.2       11800                                    Avatar
# 1           6.9        4500  Pirates of the Caribbean: At World's End
# 2           6.3        4466                                   Spectre
# 3           7.6        9106                     The Dark Knight Rises
# 4           6.1        2124                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
# dropping null values to avoid errors in the future
combined_data.dropna(inplace = True) 
combined_data.count()
# Out:
# id                      4800
# original_title          4800
# runtime                 4800
# genres                  4800
# production_companies    4800
# release_date            4800
# popularity              4800
# vote_average            4800
# vote_count              4800
# title                   4800
# cast                    4800
# crew                    4800
# dtype: int64

# %%
# the "genres" column includes up to 4 genres one movie can belong to, so we want to have 4 columns for genres of each movie
new = combined_data["genres"].str.split(",", n = 7, expand = True) 
new.columns = ["1", "genre_1", "2", "genre_2", "3", "genre_3", "4", "genre_4"]
new.head()
# Out:
#             1                genre_1           2                genre_2  \
# 0  [{"id": 28      "name": "Action"}   {"id": 12   "name": "Adventure"}
# 1  [{"id": 12   "name": "Adventure"}   {"id": 14     "name": "Fantasy"}
# 2  [{"id": 28      "name": "Action"}   {"id": 12   "name": "Adventure"}
# 3  [{"id": 28      "name": "Action"}   {"id": 80       "name": "Crime"}
# 4  [{"id": 28      "name": "Action"}   {"id": 12   "name": "Adventure"}
#
#              3                       genre_3            4  \
# 0    {"id": 14            "name": "Fantasy"}   {"id": 878
# 1    {"id": 28            "name": "Action"}]         None
# 2    {"id": 80             "name": "Crime"}]         None
# 3    {"id": 18              "name": "Drama"}    {"id": 53
# 4   {"id": 878   "name": "Science Fiction"}]         None
#
#                         genre_4
# 0   "name": "Science Fiction"}]
# 1                          None
# 2                          None
# 3          "name": "Thriller"}]
# 4                          None

# %%
# cleaning the string values within genres from unnecessary characters
new = new[ [ 'genre_1', 'genre_2', 'genre_3', 'genre_4'] ] 
new["genre_1"] = new["genre_1"].str.replace('name', '').str.lstrip('": "').str.rstrip('"}]')
new["genre_2"] = new["genre_2"].str.replace('name', '').str.lstrip('": "').str.rstrip('"}]')
new["genre_3"] = new["genre_3"].str.replace('name', '').str.lstrip('": "').str.rstrip('"}]')
new["genre_4"] = new["genre_4"].str.replace('name', '').str.lstrip('": "').str.rstrip('"}]')
movie_id = combined_data["id"]
new = new.join(movie_id)
new.head()
# Out:
#      genre_1    genre_2          genre_3          genre_4      id
# 0     Action  Adventure          Fantasy  Science Fiction   19995
# 1  Adventure    Fantasy           Action             None     285
# 2     Action  Adventure            Crime             None  206647
# 3     Action      Crime            Drama         Thriller   49026
# 4     Action  Adventure  Science Fiction             None   49529

# %%
# merging the new 4 genres columns with the "combined" dataset
result = pd.concat([combined_data, new], axis=1, sort=False)
result.drop("genres", axis=1)
result = result[ ['id', 'original_title', 'runtime', 'genre_1', 'genre_2', 'genre_3', 'genre_4', 'production_companies', 'cast', 'crew', 'release_date', 'popularity', 'vote_average', 'vote_count'] ]
result = result.loc[:,~result.columns.duplicated()]
result.head()
# Out:
#        id                            original_title  runtime    genre_1  \
# 0   19995                                    Avatar    162.0     Action
# 1     285  Pirates of the Caribbean: At World's End    169.0  Adventure
# 2  206647                                   Spectre    148.0     Action
# 3   49026                     The Dark Knight Rises    165.0     Action
# 4   49529                               John Carter    132.0     Action
#
#      genre_2          genre_3          genre_4  \
# 0  Adventure          Fantasy  Science Fiction
# 1    Fantasy           Action             None
# 2  Adventure            Crime             None
# 3      Crime            Drama         Thriller
# 4  Adventure  Science Fiction             None
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew release_date  popularity  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...   2009-12-10  150.437577
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...   2007-05-19  139.082615
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...   2015-10-26  107.376788
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...   2012-07-16  112.312950
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...   2012-03-07   43.926995
#
#    vote_average  vote_count
# 0           7.2       11800
# 1           6.9        4500
# 2           6.3        4466
# 3           7.6        9106
# 4           6.1        2124

# %%
# loading another dataset with more than 80K movies that has important info like movies' income
another = pd.read_csv("imdb_movies.csv")
another
# Out:
# /Users/KIM/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# 4                           L'Inferno  1911     1911-03-06
# ...                               ...   ...            ...
# 85850                         Le lion  2020     2020-01-29
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 85853               Sokagin Çocuklari  2019     2019-03-15
# 85854      La vida sense la Sara Amat  2019     2020-02-05
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                   director  ...  \
# 0                          Alexander Black  ...
# 1                             Charles Tait  ...
# 2                                Urban Gad  ...
# 3                       Charles L. Gaskill  ...
# 4      Francesco Bertolini, Adolfo Padovan  ...
# ...                                    ...  ...
# 85850               Ludovic Colbeau-Justin  ...
# 85851                      Johan Nijenhuis  ...
# 85852                      Vineesh Aaradya  ...
# 85853                    Ahmet Faik Akinci  ...
# 85854                            Laura Jou  ...
#
#                                                   actors  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# ...                                                  ...
# 85850  Dany Boon, Philippe Katerine, Anne Serra, Samu...
# 85851  Herman Finkers, Johanna ter Steege, Leonie ter...
# 85852  Anoop Chandran, Indrans, Sona Nair, Simon Brit...
# 85853  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
# 85854  Maria Morera Colomer, Biel Rossell Pelfort, Is...
#
#                                              description avg_vote votes  \
# 0      The adventures of a female reporter in the 1890s.      5.9   154
# 1      True story of notorious Australian outlaw Ned ...      6.1   589
# 2      Two men of high rank are both wooing the beaut...      5.8   188
# 3      The fabled queen of Egypt's affair with Roman ...      5.2   446
# 4      Loosely adapted from Dante's Divine Comedy and...      7.0  2237
# ...                                                  ...      ...   ...
# 85850  A psychiatric hospital patient pretends to be ...      5.3   398
# 85851  A middle-aged veterinary surgeon believes his ...      7.7   724
# 85852                                                NaN      7.9   265
# 85853                                                NaN      6.4   194
# 85854  Pep, a 13-year-old boy, is in love with a girl...      6.7   102
#
#         budget  usa_gross_income worlwide_gross_income metascore  \
# 0          NaN               NaN                   NaN       NaN
# 1       $ 2250               NaN                   NaN       NaN
# 2          NaN               NaN                   NaN       NaN
# 3      $ 45000               NaN                   NaN       NaN
# 4          NaN               NaN                   NaN       NaN
# ...        ...               ...                   ...       ...
# 85850      NaN               NaN             $ 3507171       NaN
# 85851      NaN               NaN             $ 7299062       NaN
# 85852      NaN               NaN                   NaN       NaN
# 85853      NaN               NaN                $ 2833       NaN
# 85854      NaN               NaN               $ 59794       NaN
#
#       reviews_from_users  reviews_from_critics
# 0                    1.0                   2.0
# 1                    7.0                   7.0
# 2                    5.0                   2.0
# 3                   25.0                   3.0
# 4                   31.0                  14.0
# ...                  ...                   ...
# 85850                NaN                   4.0
# 85851                6.0                   4.0
# 85852                NaN                   NaN
# 85853                NaN                   NaN
# 85854                NaN                   2.0
#
# [85855 rows x 22 columns]

# %%
# checking how many movies from our dataset are also in the big "another "dataset + adding the column with True/False
yes = another['original_title'].isin(result['original_title'])
another['includes_our_movie'] = yes
another.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income  worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                    NaN       NaN                1.0
# 1               NaN                    NaN       NaN                7.0
# 2               NaN                    NaN       NaN                5.0
# 3               NaN                    NaN       NaN               25.0
# 4               NaN                    NaN       NaN               31.0
#
#   reviews_from_critics  includes_our_movie
# 0                  2.0               False
# 1                  7.0               False
# 2                  2.0               False
# 3                  3.0                True
# 4                 14.0               False
#
# [5 rows x 23 columns]

# %%
# updating "another" dataset to have only those movies that we have in our "result" dataset
only_needed_another = another.loc[another["includes_our_movie"], :].dropna()
only_needed_another
# Out:
#       imdb_title_id                            title  \
# 506       tt0017136                       Metropolis
# 2454      tt0027977                    Tempi moderni
# 2827      tt0029583        Biancaneve e i sette nani
# 3266      tt0031381                    Via col vento
# 3348      tt0031679        Mr. Smith va a Washington
# ...             ...                              ...
# 79742     tt6139732                          Aladdin
# 79820     tt6164502                         November
# 80644     tt6476140  Serenity - L'isola dell'inganno
# 81178     tt6772950                 Obbligo o verità
# 84553     tt8663516             La bambola assassina
#
#                         original_title  year date_published  \
# 506                         Metropolis  1927     1928-10-01
# 2454                      Modern Times  1936     1937-03-12
# 2827   Snow White and the Seven Dwarfs  1937     1938-11-30
# 3266                Gone with the Wind  1939     1949-03-12
# 3348      Mr. Smith Goes to Washington  1939     1947-04-05
# ...                                ...   ...            ...
# 79742                          Aladdin  2019     2019-05-22
# 79820                         November  2017     2017-02-03
# 80644                         Serenity  2019     2019-07-18
# 81178                    Truth or Dare  2018     2018-06-21
# 84553                     Child's Play  2019     2019-06-19
#
#                             genre  duration             country  \
# 506                 Drama, Sci-Fi       153             Germany
# 2454        Comedy, Drama, Family        87                 USA
# 2827   Animation, Family, Fantasy        83                 USA
# 3266      Drama, History, Romance       238                 USA
# 3348                Comedy, Drama       129                 USA
# ...                           ...       ...                 ...
# 79742  Adventure, Family, Fantasy       128  UK, USA, Australia
# 79820      Drama, Fantasy, Horror       115             Estonia
# 80644    Drama, Mystery, Thriller       106             UK, USA
# 81178            Horror, Thriller       100                 USA
# 84553              Horror, Sci-Fi        90         Canada, USA
#
#                         language                      director  ...  \
# 506                       German                    Fritz Lang  ...
# 2454                     English               Charles Chaplin  ...
# 2827                     English  William Cottrell, David Hand  ...
# 3266                     English  Victor Fleming, George Cukor  ...
# 3348                     English                   Frank Capra  ...
# ...                          ...                           ...  ...
# 79742            English, Arabic                   Guy Ritchie  ...
# 79820  Estonian, German, Italian                 Rainer Sarnet  ...
# 80644            English, French                 Steven Knight  ...
# 81178           English, Spanish                   Jeff Wadlow  ...
# 84553        English, Vietnamese                 Lars Klevberg  ...
#
#                                              description avg_vote   votes  \
# 506    In a futuristic city sharply divided between t...      8.3  156076
# 2454   The Tramp struggles to live in modern industri...      8.5  211250
# 2827   Exiled into the dangerous forest by her wicked...      7.6  177157
# 3266   A manipulative woman and a roguish man conduct...      8.1  283975
# 3348   A naive man is appointed to fill a vacancy in ...      8.1  104547
# ...                                                  ...      ...     ...
# 79742  A kind-hearted street urchin and a power-hungr...      7.0  215140
# 79820  In a poor Estonian village, a group of peasant...      7.2    3752
# 80644  A fishing boat captain juggles facing his myst...      5.4   33464
# 81178  A harmless game of Truth or Dare among friends...      5.2   45088
# 84553  A mother gives her 13-year-old son a toy doll ...      5.8   41215
#
#             budget  usa_gross_income  worlwide_gross_income metascore  \
# 506    DEM 6000000         $ 1236166              $ 1349711      98.0
# 2454     $ 1500000          $ 163577               $ 457688      96.0
# 2827     $ 1499000       $ 184925486            $ 184925486      95.0
# 3266     $ 3977000       $ 200852579            $ 402352579      97.0
# 3348     $ 1900000          $ 144738               $ 144738      73.0
# ...            ...               ...                    ...       ...
# 79742  $ 183000000       $ 355559216           $ 1050693953      53.0
# 79820  EUR 1450000           $ 19084                $ 19084      79.0
# 80644   $ 25000000         $ 8547045             $ 14454622      37.0
# 81178    $ 3500000        $ 41411015             $ 95330493      35.0
# 84553   $ 10000000        $ 29208403             $ 44902237      48.0
#
#       reviews_from_users reviews_from_critics  includes_our_movie
# 506                495.0                208.0                True
# 2454               307.0                115.0                True
# 2827               260.0                173.0                True
# 3266               881.0                197.0                True
# 3348               296.0                 88.0                True
# ...                  ...                  ...                 ...
# 79742             2299.0                349.0                True
# 79820               25.0                 69.0                True
# 80644              581.0                173.0                True
# 81178              451.0                210.0                True
# 84553              916.0                277.0                True
#
# [3608 rows x 23 columns]

# %%
cleaned_another = only_needed_another[['original_title', 'country', 'director', 'actors', 'budget', 'usa_gross_income', 'worlwide_gross_income' ]]
cleaned_another.count()
# Out:
# original_title           3608
# country                  3608
# director                 3608
# actors                   3608
# budget                   3608
# usa_gross_income         3608
# worlwide_gross_income    3608
# dtype: int64

# %%
# merging two datasets based on the movie titles
final = result.merge(cleaned_another,how='inner', on="original_title")
final
# Out:
#           id                            original_title  runtime  \
# 0      19995                                    Avatar    162.0
# 1        285  Pirates of the Caribbean: At World's End    169.0
# 2     206647                                   Spectre    148.0
# 3      49026                     The Dark Knight Rises    165.0
# 4      49529                               John Carter    132.0
# ...      ...                                       ...      ...
# 3604   24055                           The Puffy Chair     85.0
# 3605   44990                          Breaking Upwards     88.0
# 3606   39851                                     Clean    111.0
# 3607   14337                                    Primer     77.0
# 3608   67238                                    Cavite     80.0
#
#               genre_1    genre_2          genre_3          genre_4  \
# 0              Action  Adventure          Fantasy  Science Fiction
# 1           Adventure    Fantasy           Action             None
# 2              Action  Adventure            Crime             None
# 3              Action      Crime            Drama         Thriller
# 4              Action  Adventure  Science Fiction             None
# ...               ...        ...              ...              ...
# 3604            Drama     Comedy          Romance             None
# 3605           Comedy    Romance             None             None
# 3606            Drama       None             None             None
# 3607  Science Fiction      Drama         Thriller             None
# 3608          Foreign   Thriller             None             None
#
#                                    production_companies  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                 ...
# 3604                                                 []
# 3605                                                 []
# 3606                                                 []
# 3607                 [{"name": "Thinkfilm", "id": 446}]
# 3608                                                 []
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     [{"cast_id": 5, "character": "John Carter", "c...
# ...                                                 ...
# 3604  [{"cast_id": 4, "character": "Josh", "credit_i...
# 3605  [{"cast_id": 1, "character": "Zoe", "credit_id...
# 3606  [{"cast_id": 1, "character": "Emily Wang", "cr...
# 3607  [{"cast_id": 1, "character": "Aaron", "credit_...
# 3608                                                 []
#
#                                                    crew release_date  \
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...   2009-12-10
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...   2007-05-19
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...   2015-10-26
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...   2012-07-16
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...   2012-03-07
# ...                                                 ...          ...
# 3604  [{"credit_id": "52fe447fc3a368484e026881", "de...   2005-01-17
# 3605  [{"credit_id": "572239efc3a368712a0007db", "de...   2009-03-14
# 3606  [{"credit_id": "52fe47369251416c9106db9b", "de...   2004-09-01
# 3607  [{"credit_id": "52fe45e79251416c75066791", "de...   2004-10-08
# 3608  [{"credit_id": "52fe475dc3a368484e0c319f", "de...   2005-03-12
#
#       popularity  vote_average  vote_count  \
# 0     150.437577           7.2       11800
# 1     139.082615           6.9        4500
# 2     107.376788           6.3        4466
# 3     112.312950           7.6        9106
# 4      43.926995           6.1        2124
# ...          ...           ...         ...
# 3604    1.243955           6.2          15
# 3605    0.674570           5.6          12
# 3606    1.464566           6.7          17
# 3607   23.307949           6.9         658
# 3608    0.022173           7.5           2
#
#                                        country                       director  \
# 0                                          USA                  James Cameron
# 1                                          USA                 Gore Verbinski
# 2     UK, USA, Austria, Mexico, Italy, Morocco                     Sam Mendes
# 3                                      UK, USA              Christopher Nolan
# 4                                          USA                 Andrew Stanton
# ...                                        ...                            ...
# 3604                                       USA      Jay Duplass, Mark Duplass
# 3605                                       USA                     Daryl Wein
# 3606                        France, Canada, UK                Olivier Assayas
# 3607                                       USA                  Shane Carruth
# 3608                          Philippines, USA  Neill Dela Llana, Ian Gamazon
#
#                                                  actors       budget  \
# 0     Sam Worthington, Zoe Saldana, Sigourney Weaver...  $ 237000000
# 1     Johnny Depp, Geoffrey Rush, Orlando Bloom, Kei...  $ 300000000
# 2     Daniel Craig, Christoph Waltz, Léa Seydoux, Ra...  $ 245000000
# 3     Christian Bale, Gary Oldman, Tom Hardy, Joseph...  $ 250000000
# 4     Taylor Kitsch, Lynn Collins, Samantha Morton, ...  $ 250000000
# ...                                                 ...          ...
# 3604  Mark Duplass, Katie Aselton, Rhett Wilkins, Ju...      $ 15000
# 3605  Zoe Lister-Jones, Daryl Wein, Julie White, And...      $ 15000
# 3606  Maggie Cheung, Nick Nolte, Béatrice Dalle, Jea...     GBP 4500
# 3607  Shane Carruth, David Sullivan, Casey Gooden, A...       $ 7000
# 3608  Ian Gamazon, Edwin Lagda, Edgar Tancangco, Nor...       $ 7000
#
#      usa_gross_income worlwide_gross_income
# 0         $ 760507625          $ 2790439092
# 1         $ 309420425           $ 960996492
# 2         $ 200074609           $ 880674609
# 3         $ 448139099          $ 1081133191
# 4          $ 73078100           $ 284139100
# ...               ...                   ...
# 3604         $ 194523              $ 195254
# 3605          $ 77389               $ 77389
# 3606         $ 138711             $ 2971219
# 3607         $ 424760              $ 545436
# 3608          $ 70071               $ 70071
#
# [3609 rows x 20 columns]

# %%
# sorting from highest popularity to lowest
final.sort_values(by=["popularity"],ascending=False)
# Out:
#           id                    original_title  runtime    genre_1  \
# 544   211672                           Minions     91.0     Family
# 95    157336                      Interstellar    169.0  Adventure
# 775   293660                          Deadpool    108.0     Action
# 94    118340           Guardians of the Galaxy    121.0     Action
# 125    76341                Mad Max: Fury Road    120.0     Action
# ...      ...                               ...      ...        ...
# 3492   78705                      Cama adentro     83.0      Drama
# 3536   64499                       Quinceañera     90.0      Drama
# 2905   55903  Betty Fisher et autres histoires    103.0      Drama
# 3608   67238                            Cavite     80.0    Foreign
# 3550   91721                 Nothing But a Man     95.0      Drama
#
#               genre_2          genre_3   genre_4  \
# 544         Animation        Adventure    Comedy
# 95              Drama  Science Fiction      None
# 775         Adventure           Comedy      None
# 94    Science Fiction        Adventure      None
# 125         Adventure  Science Fiction  Thriller
# ...               ...              ...       ...
# 3492          Foreign             None      None
# 3536             None             None      None
# 2905         Thriller            Crime   Foreign
# 3608         Thriller             None      None
# 3550             None             None      None
#
#                                    production_companies  \
# 544   [{"name": "Universal Pictures", "id": 33}, {"n...
# 95    [{"name": "Paramount Pictures", "id": 4}, {"na...
# 775   [{"name": "Twentieth Century Fox Film Corporat...
# 94    [{"name": "Marvel Studios", "id": 420}, {"name...
# 125   [{"name": "Village Roadshow Pictures", "id": 7...
# ...                                                 ...
# 3492  [{"name": "Libido Cine", "id": 28810}, {"name"...
# 3536                                                 []
# 2905                                                 []
# 3608                                                 []
# 3550  [{"name": "DuArt Film and Video", "id": 34166}...
#
#                                                    cast  \
# 544   [{"cast_id": 22, "character": "Scarlet Overkil...
# 95    [{"cast_id": 9, "character": "Joseph Cooper", ...
# 775   [{"cast_id": 99, "character": "Wade Wilson / D...
# 94    [{"cast_id": 1, "character": "Peter Quill / St...
# 125   [{"cast_id": 2, "character": "Max Rockatansky"...
# ...                                                 ...
# 3492  [{"cast_id": 1001, "character": "Beba Pujol", ...
# 3536  [{"cast_id": 3, "character": "Magdalena", "cre...
# 2905  [{"cast_id": 4, "character": "Betty Fisher", "...
# 3608                                                 []
# 3550  [{"cast_id": 1054, "character": "Duff Anderson...
#
#                                                    crew release_date  \
# 544   [{"credit_id": "5431b2b10e0a2656e20026c7", "de...   2015-06-17
# 95    [{"credit_id": "52fe4bbf9251416c910e4801", "de...   2014-11-05
# 775   [{"credit_id": "56c986b2925141172f0068b6", "de...   2016-02-09
# 94    [{"credit_id": "538ce329c3a3687155003358", "de...   2014-07-30
# 125   [{"credit_id": "577da370c3a36817f8003838", "de...   2015-05-13
# ...                                                 ...          ...
# 3492  [{"credit_id": "52fe49afc3a368484e138b55", "de...   2004-09-21
# 3536  [{"credit_id": "552e417092514174db006c46", "de...   2006-06-05
# 2905  [{"credit_id": "58ade9aec3a36861d6000653", "de...   2001-09-01
# 3608  [{"credit_id": "52fe475dc3a368484e0c319f", "de...   2005-03-12
# 3550  [{"credit_id": "52fe48e29251416c750b656b", "de...   1964-01-01
#
#       popularity  vote_average  vote_count                  country  \
# 544   875.581305           6.4        4571                      USA
# 95    724.247784           8.1       10867          USA, UK, Canada
# 775   514.569956           7.4       10995                      USA
# 94    481.098624           7.9        9742                      USA
# 125   434.278564           7.2        9427  Australia, South Africa
# ...          ...           ...         ...                      ...
# 3492    0.038706           7.8           3         Argentina, Spain
# 3536    0.034135           7.0           7                      USA
# 2905    0.024186           7.0           3           France, Canada
# 3608    0.022173           7.5           2         Philippines, USA
# 3550    0.008453           7.0           2                      USA
#
#                                 director  \
# 544            Kyle Balda, Pierre Coffin
# 95                     Christopher Nolan
# 775                           Tim Miller
# 94                            James Gunn
# 125                        George Miller
# ...                                  ...
# 3492                       Jorge Gaggero
# 3536  Richard Glatzer, Wash Westmoreland
# 2905                       Claude Miller
# 3608       Neill Dela Llana, Ian Gamazon
# 3550                      Michael Roemer
#
#                                                  actors        budget  \
# 544   Sandra Bullock, Jon Hamm, Michael Keaton, Alli...    $ 74000000
# 95    Ellen Burstyn, Matthew McConaughey, Mackenzie ...   $ 165000000
# 775   Ryan Reynolds, Karan Soni, Ed Skrein, Michael ...    $ 58000000
# 94    Chris Pratt, Zoe Saldana, Dave Bautista, Vin D...   $ 170000000
# 125   Tom Hardy, Charlize Theron, Nicholas Hoult, Hu...   $ 150000000
# ...                                                 ...           ...
# 3492  Norma Aleandro, Norma Argentina, Marcos Mundst...      $ 800000
# 3536  Jesus Castanos, Araceli Guzman-Rico, Emily Rio...      $ 400000
# 2905  Sandrine Kiberlain, Nicole Garcia, Mathilde Se...  FRF 50000000
# 3608  Ian Gamazon, Edwin Lagda, Edgar Tancangco, Nor...        $ 7000
# 3550  Ivan Dixon, Abbey Lincoln, Julius Harris, Glor...      $ 160000
#
#      usa_gross_income worlwide_gross_income
# 544       $ 336045770          $ 1159443129
# 95        $ 188020017           $ 696742056
# 775       $ 363070709           $ 782612155
# 94        $ 333176600           $ 772791156
# 125       $ 154058340           $ 375225175
# ...               ...                   ...
# 3492         $ 200433              $ 618264
# 3536        $ 1692693             $ 2522787
# 2905         $ 208400              $ 676239
# 3608          $ 70071               $ 70071
# 3550          $ 13063               $ 13063
#
# [3609 rows x 20 columns]

# %%
# there is a mistake in the column named "worlwide_gross_income" and it needs a letter "d" in the word worldwide
final = final.rename(columns = {"worlwide_gross_income": "worldwide_gross_income"})

# %%
# creating a function that will remove the currency symbol from the 2 columns with gross income values to make sure these values are the float type
def clean_currency(x):
    if isinstance(x, str):
        return(x.replace('$', '').replace(',', ''))
    return(x)

# %%
final['usa_gross_income'] = final['usa_gross_income'].apply(clean_currency)

# %%
final['worldwide_gross_income'] = final['worldwide_gross_income'].apply(clean_currency)

# %%
final['release_date'] = pd.to_datetime(final['release_date'])

# %%
final
# Out:
#           id                            original_title  runtime  \
# 0      19995                                    Avatar    162.0
# 1        285  Pirates of the Caribbean: At World's End    169.0
# 2     206647                                   Spectre    148.0
# 3      49026                     The Dark Knight Rises    165.0
# 4      49529                               John Carter    132.0
# ...      ...                                       ...      ...
# 3604   24055                           The Puffy Chair     85.0
# 3605   44990                          Breaking Upwards     88.0
# 3606   39851                                     Clean    111.0
# 3607   14337                                    Primer     77.0
# 3608   67238                                    Cavite     80.0
#
#               genre_1    genre_2          genre_3          genre_4  \
# 0              Action  Adventure          Fantasy  Science Fiction
# 1           Adventure    Fantasy           Action             None
# 2              Action  Adventure            Crime             None
# 3              Action      Crime            Drama         Thriller
# 4              Action  Adventure  Science Fiction             None
# ...               ...        ...              ...              ...
# 3604            Drama     Comedy          Romance             None
# 3605           Comedy    Romance             None             None
# 3606            Drama       None             None             None
# 3607  Science Fiction      Drama         Thriller             None
# 3608          Foreign   Thriller             None             None
#
#                                    production_companies  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                 ...
# 3604                                                 []
# 3605                                                 []
# 3606                                                 []
# 3607                 [{"name": "Thinkfilm", "id": 446}]
# 3608                                                 []
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     [{"cast_id": 5, "character": "John Carter", "c...
# ...                                                 ...
# 3604  [{"cast_id": 4, "character": "Josh", "credit_i...
# 3605  [{"cast_id": 1, "character": "Zoe", "credit_id...
# 3606  [{"cast_id": 1, "character": "Emily Wang", "cr...
# 3607  [{"cast_id": 1, "character": "Aaron", "credit_...
# 3608                                                 []
#
#                                                    crew release_date  \
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...   2009-12-10
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...   2007-05-19
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...   2015-10-26
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...   2012-07-16
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...   2012-03-07
# ...                                                 ...          ...
# 3604  [{"credit_id": "52fe447fc3a368484e026881", "de...   2005-01-17
# 3605  [{"credit_id": "572239efc3a368712a0007db", "de...   2009-03-14
# 3606  [{"credit_id": "52fe47369251416c9106db9b", "de...   2004-09-01
# 3607  [{"credit_id": "52fe45e79251416c75066791", "de...   2004-10-08
# 3608  [{"credit_id": "52fe475dc3a368484e0c319f", "de...   2005-03-12
#
#       popularity  vote_average  vote_count  \
# 0     150.437577           7.2       11800
# 1     139.082615           6.9        4500
# 2     107.376788           6.3        4466
# 3     112.312950           7.6        9106
# 4      43.926995           6.1        2124
# ...          ...           ...         ...
# 3604    1.243955           6.2          15
# 3605    0.674570           5.6          12
# 3606    1.464566           6.7          17
# 3607   23.307949           6.9         658
# 3608    0.022173           7.5           2
#
#                                        country                       director  \
# 0                                          USA                  James Cameron
# 1                                          USA                 Gore Verbinski
# 2     UK, USA, Austria, Mexico, Italy, Morocco                     Sam Mendes
# 3                                      UK, USA              Christopher Nolan
# 4                                          USA                 Andrew Stanton
# ...                                        ...                            ...
# 3604                                       USA      Jay Duplass, Mark Duplass
# 3605                                       USA                     Daryl Wein
# 3606                        France, Canada, UK                Olivier Assayas
# 3607                                       USA                  Shane Carruth
# 3608                          Philippines, USA  Neill Dela Llana, Ian Gamazon
#
#                                                  actors       budget  \
# 0     Sam Worthington, Zoe Saldana, Sigourney Weaver...  $ 237000000
# 1     Johnny Depp, Geoffrey Rush, Orlando Bloom, Kei...  $ 300000000
# 2     Daniel Craig, Christoph Waltz, Léa Seydoux, Ra...  $ 245000000
# 3     Christian Bale, Gary Oldman, Tom Hardy, Joseph...  $ 250000000
# 4     Taylor Kitsch, Lynn Collins, Samantha Morton, ...  $ 250000000
# ...                                                 ...          ...
# 3604  Mark Duplass, Katie Aselton, Rhett Wilkins, Ju...      $ 15000
# 3605  Zoe Lister-Jones, Daryl Wein, Julie White, And...      $ 15000
# 3606  Maggie Cheung, Nick Nolte, Béatrice Dalle, Jea...     GBP 4500
# 3607  Shane Carruth, David Sullivan, Casey Gooden, A...       $ 7000
# 3608  Ian Gamazon, Edwin Lagda, Edgar Tancangco, Nor...       $ 7000
#
#      usa_gross_income worldwide_gross_income
# 0           760507625             2790439092
# 1           309420425              960996492
# 2           200074609              880674609
# 3           448139099             1081133191
# 4            73078100              284139100
# ...               ...                    ...
# 3604           194523                 195254
# 3605            77389                  77389
# 3606           138711                2971219
# 3607           424760                 545436
# 3608            70071                  70071
#
# [3609 rows x 20 columns]

# %%
# movie budgets are displayed in different currencies
# check how many movies out of 3608 have their budget in dollars
final["budget"].str.contains('$', regex=False).sum()
# Out:
# 3497

# %%
#find all unique currencies besides USD for future conversion
currency=final[~final["budget"].str.contains('$', regex=False)]
currency["budget"] = currency["budget"].str.replace('\d+', '')
currency["budget"].unique()
# Out:
# <ipython-input-24-8cef779a4f67>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   currency["budget"] = currency["budget"].str.replace('\d+', '')
# array(['EUR ', 'GBP ', 'CNY ', 'CAD ', 'DEM ', 'THB ', 'FRF ', 'AUD ',
#        'HUF ', 'INR ', 'DKK ', 'NOK ', 'BRL '], dtype=object)

# %%
# creating new function to convert the movie budgets into USD
def convert_rates(money):
    if 'EUR' in money:
        return int(''.join(x for x in money if x.isdigit())) * 1.17
    elif 'GBP' in money:
        return int(''.join(x for x in money if x.isdigit())) * 1.29
    elif 'CNY' in money:
        return int(''.join(x for x in money if x.isdigit())) * 0.15
    elif 'CAD' in money:
        return int(''.join(x for x in money if x.isdigit())) * 0.75
    elif 'DEM' in money:
        return int(''.join(x for x in money if x.isdigit())) * 0.6
    elif 'THB' in money:
        return int(''.join(x for x in money if x.isdigit())) * 0.032
    elif 'FRF' in money:
        return int(''.join(x for x in money if x.isdigit())) * 0.18
    elif 'AUD' in money:
        return int(''.join(x for x in money if x.isdigit())) * 0.71
    elif 'HUF' in money:
        return int(''.join(x for x in money if x.isdigit())) * 0.0033
    elif 'INR' in money:
        return int(''.join(x for x in money if x.isdigit())) * 0.014
    elif 'DKK' in money:
        return int(''.join(x for x in money if x.isdigit())) * 0.16
    elif 'NOK' in money:
        return int(''.join(x for x in money if x.isdigit())) * 0.11
    elif 'BRL' in money:
        return int(''.join(x for x in money if x.isdigit())) * 0.18
    else:
        return int(''.join(x for x in money if x.isdigit()))

# %%
# converting the movies' budgets into dollars where needed
final["budget"] = final["budget"].apply(convert_rates)

# %%
# our outcome of the data cleaning we performed so far
# the dataset we will use for summary statistics
final.head()
# Out:
#        id                            original_title  runtime    genre_1  \
# 0   19995                                    Avatar    162.0     Action
# 1     285  Pirates of the Caribbean: At World's End    169.0  Adventure
# 2  206647                                   Spectre    148.0     Action
# 3   49026                     The Dark Knight Rises    165.0     Action
# 4   49529                               John Carter    132.0     Action
#
#      genre_2          genre_3          genre_4  \
# 0  Adventure          Fantasy  Science Fiction
# 1    Fantasy           Action             None
# 2  Adventure            Crime             None
# 3      Crime            Drama         Thriller
# 4  Adventure  Science Fiction             None
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew release_date  popularity  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...   2009-12-10  150.437577
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...   2007-05-19  139.082615
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...   2015-10-26  107.376788
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...   2012-07-16  112.312950
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...   2012-03-07   43.926995
#
#    vote_average  vote_count                                   country  \
# 0           7.2       11800                                       USA
# 1           6.9        4500                                       USA
# 2           6.3        4466  UK, USA, Austria, Mexico, Italy, Morocco
# 3           7.6        9106                                   UK, USA
# 4           6.1        2124                                       USA
#
#             director                                             actors  \
# 0      James Cameron  Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 1     Gore Verbinski  Johnny Depp, Geoffrey Rush, Orlando Bloom, Kei...
# 2         Sam Mendes  Daniel Craig, Christoph Waltz, Léa Seydoux, Ra...
# 3  Christopher Nolan  Christian Bale, Gary Oldman, Tom Hardy, Joseph...
# 4     Andrew Stanton  Taylor Kitsch, Lynn Collins, Samantha Morton, ...
#
#         budget usa_gross_income worldwide_gross_income
# 0  237000000.0        760507625             2790439092
# 1  300000000.0        309420425              960996492
# 2  245000000.0        200074609              880674609
# 3  250000000.0        448139099             1081133191
# 4  250000000.0         73078100              284139100

# %%
genre1_df = final.loc[:, ~final.columns.isin(['genre_2', 'genre_3', 'genre_4'])]
genre2_df = final.loc[:, ~final.columns.isin(['genre_1', 'genre_3', 'genre_4'])]
genre3_df = final.loc[:, ~final.columns.isin(['genre_1', 'genre_2', 'genre_4'])]
genre4_df = final.loc[:, ~final.columns.isin(['genre_1', 'genre_2', 'genre_3'])]

genre1_df = genre1_df.rename(columns={"genre_1": "genre"})
genre2_df = genre2_df.rename(columns={"genre_2": "genre"})
genre3_df = genre3_df.rename(columns={"genre_3": "genre"})
genre4_df = genre4_df.rename(columns={"genre_4": "genre"})

genre2_df = genre2_df[genre2_df['genre'] != 'None']
genre3_df = genre3_df[genre3_df['genre'] != 'None']
genre4_df = genre4_df[genre4_df['genre'] != 'None']

frames = [genre1_df, genre2_df, genre3_df, genre4_df]
genre_df = pd.concat(frames)

genre_df = genre_df.sort_values(['genre'])
# genre_df.sort_values(by=['genre'])


# pd.set_option("display.max_rows", None, "display.max_columns", None)
# print(genre_df['genre'])

genre_table = genre_df.groupby('genre').count()
genre_table.head()
# Out:
#                                        id  original_title  runtime  \
# genre
# Action                                912             912      912
# Action"}, {"id": 10749, "": "Romance    1               1        1
# Action"}, {"id": 35, "": "Comedy        3               3        3
# Action"}, {"id": 36, "": "History       1               1        1
# Action"}, {"id": 53, "": "Thriller      1               1        1
#
#                                       production_companies  cast  crew  \
# genre
# Action                                                 912   912   912
# Action"}, {"id": 10749, "": "Romance                     1     1     1
# Action"}, {"id": 35, "": "Comedy                         3     3     3
# Action"}, {"id": 36, "": "History                        1     1     1
# Action"}, {"id": 53, "": "Thriller                       1     1     1
#
#                                       release_date  popularity  vote_average  \
# genre
# Action                                         912         912           912
# Action"}, {"id": 10749, "": "Romance             1           1             1
# Action"}, {"id": 35, "": "Comedy                 3           3             3
# Action"}, {"id": 36, "": "History                1           1             1
# Action"}, {"id": 53, "": "Thriller               1           1             1
#
#                                       vote_count  country  director  actors  \
# genre
# Action                                       912      912       912     912
# Action"}, {"id": 10749, "": "Romance           1        1         1       1
# Action"}, {"id": 35, "": "Comedy               3        3         3       3
# Action"}, {"id": 36, "": "History              1        1         1       1
# Action"}, {"id": 53, "": "Thriller             1        1         1       1
#
#                                       budget  usa_gross_income  \
# genre
# Action                                   912               912
# Action"}, {"id": 10749, "": "Romance       1                 1
# Action"}, {"id": 35, "": "Comedy           3                 3
# Action"}, {"id": 36, "": "History          1                 1
# Action"}, {"id": 53, "": "Thriller         1                 1
#
#                                       worldwide_gross_income
# genre
# Action                                                   912
# Action"}, {"id": 10749, "": "Romance                       1
# Action"}, {"id": 35, "": "Comedy                           3
# Action"}, {"id": 36, "": "History                          1
# Action"}, {"id": 53, "": "Thriller                         1

# %%
genre_df['genre'].value_counts().plot(kind='bar')

# %%
mean_by_genre = genre_df.groupby('genre').mean()
mean_by_genre.head()
# Out:
#                                                  id     runtime  popularity  \
# genre
# Action                                 42164.230263  111.797149   37.208298
# Action"}, {"id": 10749, "": "Romance   10705.000000  137.000000    4.641006
# Action"}, {"id": 35, "": "Comedy       68415.333333   97.666667   79.447378
# Action"}, {"id": 36, "": "History     205775.000000  122.000000   50.767332
# Action"}, {"id": 53, "": "Thriller     11495.000000  114.000000   11.379652
#
#                                       vote_average   vote_count        budget
# genre
# Action                                    6.082895  1393.655702  6.218259e+07
# Action"}, {"id": 10749, "": "Romance      7.400000    71.000000  9.000000e+06
# Action"}, {"id": 35, "": "Comedy          6.233333  2291.000000  9.066667e+07
# Action"}, {"id": 36, "": "History         6.500000  1276.000000  1.000000e+08
# Action"}, {"id": 53, "": "Thriller        5.900000   173.000000  1.500000e+07

# %%
genre_timestamp = genre_df.loc[:, genre_df.columns.isin(['genre', 'release_date'])]
genre_timestamp.head()
# Out:
#        genre release_date
# 0     Action   2009-12-10
# 82    Action   2014-05-28
# 1463  Action   1990-03-02
# 97    Action   2012-11-26
# 1459  Action   1994-06-09

# %% [markdown]
# ## Questions for reviewers
# - How would you distribute the significance of each genre for movies with multiple genres?
